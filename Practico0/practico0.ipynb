# %% [markdown]
# # Tipos notables de gráficos

# %% [markdown]
# #### IMPORTANTE: Instalar siempre las dependencias con poetry install

# %% [markdown]
# A continuación se explicarán distintos tipo de visualizaciones de datos acompañadas de código de ejemplo para cada una.

# %% [markdown]
# **Histograma:**
# Un histograma representa la distribución de una variable numérica para uno o varios grupos. Los valores se dividen en intervalos (*bins*), y cada intervalo se representa como una barra.
# 🔗 [Más información](https://python-graph-gallery.com/histogram/)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.set_theme(style="darkgrid")


df = sns.load_dataset("iris")

sns.displot(df["sepal_length"],
            kde=False,
            rug=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# **Boxplot (“diagrama de caja y línea”):**
# Un *boxplot* resume la distribución de una variable numérica para uno o varios grupos. Permite obtener rápidamente la mediana, los cuartiles y los valores atípicos, pero oculta los puntos de datos individuales del conjunto.
# 🔗 [Más información](https://python-graph-gallery.com/boxplot/)

# %%
sns.set_theme(style="darkgrid")
df = sns.load_dataset('iris')
 
ax = sns.boxplot(x="species", y="sepal_length", data=df)

medians = df.groupby(['species'])['sepal_length'].median().values
nobs = df['species'].value_counts().values
nobs = [str(x) for x in nobs.tolist()]
nobs = ["n: " + i for i in nobs]
 

pos = range(len(nobs))
for tick,label in zip(pos,ax.get_xticklabels()):
    ax.text(pos[tick],
            medians[tick] + 0.03,
            nobs[tick],
            horizontalalignment='center',
            size='x-small',
            color='w',
            weight='semibold')
 
plt.show()

# %% [markdown]
# **Diagrama lineal:**
# Un diagrama lineal muestra la evolución de una o varias variables numéricas continuas.
# 🔗 [Más información](https://python-graph-gallery.com/line-chart/)

# %%
df = pd.DataFrame({
    'x_values': range(1,11),
    'y1_values': np.random.randn(10),
    'y2_values': np.random.randn(10)+range(1,11),
    'y3_values': np.random.randn(10)+range(11,21)
    }
)

plt.plot(
    'x_values', 'y1_values', data=df,
    marker='o', 
    markerfacecolor='blue',
    markersize=8, 
    color='skyblue',
    linewidth=4 
)

plt.plot(
    'x_values', 'y2_values', data=df,
    marker='', 
    color='olive',
    linewidth=2 
)

plt.plot(
    'x_values', 'y3_values', data=df,
    marker='', 
    color='darkred', 
    linewidth=3, 
    linestyle='dashed', 
    label="toto" 
)

plt.legend()

plt.show()

# %% [markdown]
# **Series temporales:**
# Los gráficos de series temporales incluyen todos los gráficos que representan la evolución de un valor numérico. Gráficos de líneas, *streamgraph*, diagramas de barras y gráficos de área se utilizan para la visualización de series temporales.
# 🔗 [Más información](https://python-graph-gallery.com/timeseries/)

# %%
my_count = ["France", "USA", "Japan", "Brazil"]


df = pd.DataFrame({
    "country": np.repeat(my_count, 10),
    "years": list(range(2000, 2010)) * 4,
    "value": np.random.rand(40)
})


g = sns.FacetGrid(df, col='country', hue='country', col_wrap=2) 


g = g.map(plt.plot, 'years', 'value')
g = g.map(plt.fill_between, 'years', 'value', alpha=0.2).set_titles("{col_name}")

plt.subplots_adjust(top=0.85)
g.fig.suptitle('Evolución del valor en 4 países')


plt.show()

# %% [markdown]
# **Diagrama de coordenadas paralelas (o “diagrama paralelo”):**
# Un diagrama paralelo permite comparar las características de varias observaciones individuales (series) en un conjunto de variables numéricas.
# 🔗 [Más información](https://python-graph-gallery.com/parallel-plot/)

# %%
from pandas.plotting import parallel_coordinates

data = sns.load_dataset('iris')

parallel_coordinates(data, 'species', colormap=plt.get_cmap("Set2"))
plt.show()

# %% [markdown]
# **Gráfico de dispersión (*Scatter Plot*):**
# Un gráfico de dispersión muestra la relación entre dos variables numéricas, una representada en el eje X (horizontal) y la otra en el eje Y (vertical). Cada punto de datos se representa como un círculo.
# 🔗 [Más información](https://python-graph-gallery.com/scatter-plot/)

# %%
df = sns.load_dataset('iris')
sns.scatterplot(x=df["petal_length"], y=df["petal_width"], hue=df["species"])
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# **Gráficos de líneas con bandas de error (Errorband Lineplot):**
# Es un gráfico de líneas que muestra la evolución de una variable numérica a lo largo del tiempo o en diferentes condiciones, con una banda de error sombreada alrededor de la línea principal. Esta banda representa la incertidumbre o la variabilidad en los datos, como el intervalo de confianza o la desviación estándar.
# Se usan cuando hay múltiples mediciones por cada punto en el eje X y sea relevante mostrar la variabilidad de los datos.

# %%
sns.set_theme(style="darkgrid")

fmri = sns.load_dataset("fmri")

sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# # Ejercicio de Visualización de Datos
#
# Este cuaderno contiene varios ejercicios de visualización de datos utilizando bibliotecas de Python como Matplotlib, Seaborn y Pandas.

# %%
titanic_data = sns.load_dataset("titanic")

print("Vista previa del conjunto de datos Titanic:")
print(titanic_data.head())
# Out:
# Vista previa del conjunto de datos Titanic:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Ejercicio 1:
# 1.1)
# Dado el dataset anterior, realizar un diagrama de caja para la edad promedio y desviación de edad por sexo y clase

# %% [markdown]
# 1.2)
# Realizar un histograma para el recuento de pasajeros por ciudad de embarque

# %% [markdown]
# ## Ejercicio 2:

# %%
anscombe_data = sns.load_dataset("anscombe")

print("Vista previa del conjunto de datos Anscombe:")
print(anscombe_data.head())

#Conjunto de datos que se quiere visualizar
dataset = anscombe_data[anscombe_data['dataset'].isin(['II', 'III'])]
# Out:
# Vista previa del conjunto de datos Anscombe:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %% [markdown]
# 2.1)
# Dado el conjunto de datos anterior, se quiere estudiar la posición relativa de los puntos (x,y) para saber si las variables x e y están correlacionadas, ¿Cuál gráfica es la más adecuada para mostrarlo? Impleméntelo.

# %% [markdown]
# ## Ejercicio 3

# %%
flights_data = sns.load_dataset("flights")

print("\nVista previa del conjunto de datos de Vuelos:")
print(flights_data.head())
# Out:
# Vista previa del conjunto de datos de Vuelos:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# 3.1) En base a los datos de pasajeros por vuelos, se quiere visualizar el incremento de pasajeros en función del tiempo, ¿qué gráfica puede servir para hacerlo? Implementar dicha visualización.

# %% [markdown]
# ## Ejercicio 4: Identificación de errores en visualizaciones
#
# A continuación se presentan 3 visualizaciones, cada una con un error en la elección del tipo de gráfico. Mencione qué tipo de visualización sería más adecuada (No es necesario implementarla)

# %%
plt.figure(figsize=(10, 6))
categories = ['Grupo A', 'Grupo B', 'Grupo C', 'Grupo D', 'Grupo E']
values = [23, 45, 56, 78, 92]
plt.plot(categories, values, marker='o', linewidth=2, markersize=8, color='blue')
plt.title('Error: Diagrama lineal para categorías discretas')
plt.xlabel('Categorías')
plt.ylabel('Valores')
plt.grid(True, alpha=0.3)
plt.show()


plt.figure(figsize=(10, 6))
continuous_data = np.random.uniform(0, 100, 1000) 
plt.hist(continuous_data, bins=100, color='orange', edgecolor='black')
plt.title('Error: Histograma con bins inapropiados para datos continuos')
plt.xlabel('Tiempo en segundos')
plt.ylabel('Frecuencia')
plt.grid(True, alpha=0.3)
plt.show()


df = pd.DataFrame({
    'Horas': ['Hora 1', 'Hora 2', 'Hora 2', 'Hora 3', 'Hora 3', 'Hora 3', 'Hora 3', 'Hora 1', 'Hora 4', 'Hora 4'],
    'CantidadDePersonas': [25, 30, 20, 22, 27, 30, 32, 29, 31, 40]
})
sns.boxplot(x='Horas', y='CantidadDePersonas', data=df)
plt.show()
